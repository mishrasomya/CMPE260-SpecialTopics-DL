# %% [markdown]
# ### Reference: https://github.com/drawbridge/keras-mmoe

# %%
# !git clone 'https://github.com/drawbridge/keras-mmoe.git'
# Out:
# Cloning into 'keras-mmoe'...
# remote: Enumerating objects: 61, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 61 (delta 9), reused 2 (delta 1), pack-reused 37
# Unpacking objects: 100% (61/61), done.

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras import activations, initializers, regularizers, constraints
from tensorflow.keras.layers import Layer, InputSpec

import random

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import VarianceScaling
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import roc_auc_score

# %%
SEED = 1

# Fix numpy seed for reproducibility
np.random.seed(SEED)

# Fix random seed for reproducibility
random.seed(SEED)

# Fix TensorFlow graph-level seed for reproducibility
tf.random.set_seed(SEED)

# %%
# !mkdir -p /content/data
# !wget https://github.com/drawbridge/keras-mmoe/blob/master/data/census-income.data.gz?raw=true -O /content/data/census-income.data.gz
# !wget https://github.com/drawbridge/keras-mmoe/blob/master/data/census-income.test.gz?raw=true -O /content/data/census-income.test.gz
# Out:
# --2021-11-08 20:54:20--  https://github.com/drawbridge/keras-mmoe/blob/master/data/census-income.data.gz?raw=true
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/drawbridge/keras-mmoe/raw/master/data/census-income.data.gz [following]
# --2021-11-08 20:54:20--  https://github.com/drawbridge/keras-mmoe/raw/master/data/census-income.data.gz
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/drawbridge/keras-mmoe/master/data/census-income.data.gz [following]
# --2021-11-08 20:54:20--  https://raw.githubusercontent.com/drawbridge/keras-mmoe/master/data/census-income.data.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6524338 (6.2M) [application/octet-stream]
# Saving to: ‘/content/data/census-income.data.gz’
#
# /content/data/censu 100%[===================>]   6.22M  --.-KB/s    in 0.09s
#
# 2021-11-08 20:54:21 (71.2 MB/s) - ‘/content/data/census-income.data.gz’ saved [6524338/6524338]
#
# --2021-11-08 20:54:21--  https://github.com/drawbridge/keras-mmoe/blob/master/data/census-income.test.gz?raw=true
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/drawbridge/keras-mmoe/raw/master/data/census-income.test.gz [following]
# --2021-11-08 20:54:21--  https://github.com/drawbridge/keras-mmoe/raw/master/data/census-income.test.gz
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/drawbridge/keras-mmoe/master/data/census-income.test.gz [following]
# --2021-11-08 20:54:21--  https://raw.githubusercontent.com/drawbridge/keras-mmoe/master/data/census-income.test.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3261416 (3.1M) [application/octet-stream]
# Saving to: ‘/content/data/census-income.test.gz’
#
# /content/data/censu 100%[===================>]   3.11M  --.-KB/s    in 0.07s
#
# 2021-11-08 20:54:22 (47.6 MB/s) - ‘/content/data/census-income.test.gz’ saved [3261416/3261416]

# %%
class MMoE(Layer):
    """
    Multi-gate Mixture-of-Experts model.
    """

    def __init__(self,
                 units,
                 num_experts,
                 num_tasks,
                 use_expert_bias=True,
                 use_gate_bias=True,
                 expert_activation='relu',
                 gate_activation='softmax',
                 expert_bias_initializer='zeros',
                 gate_bias_initializer='zeros',
                 expert_bias_regularizer=None,
                 gate_bias_regularizer=None,
                 expert_bias_constraint=None,
                 gate_bias_constraint=None,
                 expert_kernel_initializer='VarianceScaling',
                 gate_kernel_initializer='VarianceScaling',
                 expert_kernel_regularizer=None,
                 gate_kernel_regularizer=None,
                 expert_kernel_constraint=None,
                 gate_kernel_constraint=None,
                 activity_regularizer=None,
                 **kwargs):
        """
         Method for instantiating MMoE layer.

        :param units: Number of hidden units
        :param num_experts: Number of experts
        :param num_tasks: Number of tasks
        :param use_expert_bias: Boolean to indicate the usage of bias in the expert weights
        :param use_gate_bias: Boolean to indicate the usage of bias in the gate weights
        :param expert_activation: Activation function of the expert weights
        :param gate_activation: Activation function of the gate weights
        :param expert_bias_initializer: Initializer for the expert bias
        :param gate_bias_initializer: Initializer for the gate bias
        :param expert_bias_regularizer: Regularizer for the expert bias
        :param gate_bias_regularizer: Regularizer for the gate bias
        :param expert_bias_constraint: Constraint for the expert bias
        :param gate_bias_constraint: Constraint for the gate bias
        :param expert_kernel_initializer: Initializer for the expert weights
        :param gate_kernel_initializer: Initializer for the gate weights
        :param expert_kernel_regularizer: Regularizer for the expert weights
        :param gate_kernel_regularizer: Regularizer for the gate weights
        :param expert_kernel_constraint: Constraint for the expert weights
        :param gate_kernel_constraint: Constraint for the gate weights
        :param activity_regularizer: Regularizer for the activity
        :param kwargs: Additional keyword arguments for the Layer class
        """
        # Hidden nodes parameter
        self.units = units
        self.num_experts = num_experts
        self.num_tasks = num_tasks

        # Weight parameter
        self.expert_kernels = None
        self.gate_kernels = None
        self.expert_kernel_initializer = initializers.get(expert_kernel_initializer)
        self.gate_kernel_initializer = initializers.get(gate_kernel_initializer)
        self.expert_kernel_regularizer = regularizers.get(expert_kernel_regularizer)
        self.gate_kernel_regularizer = regularizers.get(gate_kernel_regularizer)
        self.expert_kernel_constraint = constraints.get(expert_kernel_constraint)
        self.gate_kernel_constraint = constraints.get(gate_kernel_constraint)

        # Activation parameter
        self.expert_activation = activations.get(expert_activation)
        self.gate_activation = activations.get(gate_activation)

        # Bias parameter
        self.expert_bias = None
        self.gate_bias = None
        self.use_expert_bias = use_expert_bias
        self.use_gate_bias = use_gate_bias
        self.expert_bias_initializer = initializers.get(expert_bias_initializer)
        self.gate_bias_initializer = initializers.get(gate_bias_initializer)
        self.expert_bias_regularizer = regularizers.get(expert_bias_regularizer)
        self.gate_bias_regularizer = regularizers.get(gate_bias_regularizer)
        self.expert_bias_constraint = constraints.get(expert_bias_constraint)
        self.gate_bias_constraint = constraints.get(gate_bias_constraint)

        # Activity parameter
        self.activity_regularizer = regularizers.get(activity_regularizer)

        # Keras parameter
        self.input_spec = InputSpec(min_ndim=2)
        self.supports_masking = True

        super(MMoE, self).__init__(**kwargs)

    def build(self, input_shape):
        """
        Method for creating the layer weights.

        :param input_shape: Keras tensor (future input to layer)
                            or list/tuple of Keras tensors to reference
                            for weight shape computations
        """
        assert input_shape is not None and len(input_shape) >= 2

        input_dimension = input_shape[-1]

        # Initialize expert weights (number of input features * number of units per expert * number of experts)
        self.expert_kernels = self.add_weight(
            name='expert_kernel',
            shape=(input_dimension, self.units, self.num_experts),
            initializer=self.expert_kernel_initializer,
            regularizer=self.expert_kernel_regularizer,
            constraint=self.expert_kernel_constraint,
        )

        # Initialize expert bias (number of units per expert * number of experts)
        if self.use_expert_bias:
            self.expert_bias = self.add_weight(
                name='expert_bias',
                shape=(self.units, self.num_experts),
                initializer=self.expert_bias_initializer,
                regularizer=self.expert_bias_regularizer,
                constraint=self.expert_bias_constraint,
            )

        # Initialize gate weights (number of input features * number of experts * number of tasks)
        self.gate_kernels = [self.add_weight(
            name='gate_kernel_task_{}'.format(i),
            shape=(input_dimension, self.num_experts),
            initializer=self.gate_kernel_initializer,
            regularizer=self.gate_kernel_regularizer,
            constraint=self.gate_kernel_constraint
        ) for i in range(self.num_tasks)]

        # Initialize gate bias (number of experts * number of tasks)
        if self.use_gate_bias:
            self.gate_bias = [self.add_weight(
                name='gate_bias_task_{}'.format(i),
                shape=(self.num_experts,),
                initializer=self.gate_bias_initializer,
                regularizer=self.gate_bias_regularizer,
                constraint=self.gate_bias_constraint
            ) for i in range(self.num_tasks)]

        self.input_spec = InputSpec(min_ndim=2, axes={-1: input_dimension})

        super(MMoE, self).build(input_shape)

    def call(self, inputs, **kwargs):
        """
        Method for the forward function of the layer.

        :param inputs: Input tensor
        :param kwargs: Additional keyword arguments for the base method
        :return: A tensor
        """
        gate_outputs = []
        final_outputs = []

        # f_{i}(x) = activation(W_{i} * x + b), where activation is ReLU according to the paper
        expert_outputs = tf.tensordot(a=inputs, b=self.expert_kernels, axes=1)
        # Add the bias term to the expert weights if necessary
        if self.use_expert_bias:
            expert_outputs = K.bias_add(x=expert_outputs, bias=self.expert_bias)
        expert_outputs = self.expert_activation(expert_outputs)

        # g^{k}(x) = activation(W_{gk} * x + b), where activation is softmax according to the paper
        for index, gate_kernel in enumerate(self.gate_kernels):
            gate_output = K.dot(x=inputs, y=gate_kernel)
            # Add the bias term to the gate weights if necessary
            if self.use_gate_bias:
                gate_output = K.bias_add(x=gate_output, bias=self.gate_bias[index])
            gate_output = self.gate_activation(gate_output)
            gate_outputs.append(gate_output)

        # f^{k}(x) = sum_{i=1}^{n}(g^{k}(x)_{i} * f_{i}(x))
        for gate_output in gate_outputs:
            expanded_gate_output = K.expand_dims(gate_output, axis=1)
            weighted_expert_output = expert_outputs * K.repeat_elements(expanded_gate_output, self.units, axis=1)
            final_outputs.append(K.sum(weighted_expert_output, axis=2))

        return final_outputs

    def compute_output_shape(self, input_shape):
        """
        Method for computing the output shape of the MMoE layer.

        :param input_shape: Shape tuple (tuple of integers)
        :return: List of input shape tuple where the size of the list is equal to the number of tasks
        """
        assert input_shape is not None and len(input_shape) >= 2

        output_shape = list(input_shape)
        output_shape[-1] = self.units
        output_shape = tuple(output_shape)

        return [output_shape for _ in range(self.num_tasks)]

    def get_config(self):
        """
        Method for returning the configuration of the MMoE layer.

        :return: Config dictionary
        """
        config = {
            'units': self.units,
            'num_experts': self.num_experts,
            'num_tasks': self.num_tasks,
            'use_expert_bias': self.use_expert_bias,
            'use_gate_bias': self.use_gate_bias,
            'expert_activation': activations.serialize(self.expert_activation),
            'gate_activation': activations.serialize(self.gate_activation),
            'expert_bias_initializer': initializers.serialize(self.expert_bias_initializer),
            'gate_bias_initializer': initializers.serialize(self.gate_bias_initializer),
            'expert_bias_regularizer': regularizers.serialize(self.expert_bias_regularizer),
            'gate_bias_regularizer': regularizers.serialize(self.gate_bias_regularizer),
            'expert_bias_constraint': constraints.serialize(self.expert_bias_constraint),
            'gate_bias_constraint': constraints.serialize(self.gate_bias_constraint),
            'expert_kernel_initializer': initializers.serialize(self.expert_kernel_initializer),
            'gate_kernel_initializer': initializers.serialize(self.gate_kernel_initializer),
            'expert_kernel_regularizer': regularizers.serialize(self.expert_kernel_regularizer),
            'gate_kernel_regularizer': regularizers.serialize(self.gate_kernel_regularizer),
            'expert_kernel_constraint': constraints.serialize(self.expert_kernel_constraint),
            'gate_kernel_constraint': constraints.serialize(self.gate_kernel_constraint),
            'activity_regularizer': regularizers.serialize(self.activity_regularizer)
        }
        base_config = super(MMoE, self).get_config()

        return dict(list(base_config.items()) + list(config.items()))

# %%
def data_preparation():
    # The column names are from
    # https://www2.1010data.com/documentationcenter/prod/Tutorials/MachineLearningExamples/CensusIncomeDataSet.html
    column_names = ['age', 'class_worker', 'det_ind_code', 'det_occ_code', 'education', 'wage_per_hour', 'hs_college',
                    'marital_stat', 'major_ind_code', 'major_occ_code', 'race', 'hisp_origin', 'sex', 'union_member',
                    'unemp_reason', 'full_or_part_emp', 'capital_gains', 'capital_losses', 'stock_dividends',
                    'tax_filer_stat', 'region_prev_res', 'state_prev_res', 'det_hh_fam_stat', 'det_hh_summ',
                    'instance_weight', 'mig_chg_msa', 'mig_chg_reg', 'mig_move_reg', 'mig_same', 'mig_prev_sunbelt',
                    'num_emp', 'fam_under_18', 'country_father', 'country_mother', 'country_self', 'citizenship',
                    'own_or_self', 'vet_question', 'vet_benefits', 'weeks_worked', 'year', 'income_50k']

    # Load the dataset in Pandas
    train_df = pd.read_csv(
        'data/census-income.data.gz',
        delimiter=',',
        header=None,
        index_col=None,
        names=column_names
    )
    other_df = pd.read_csv(
        'data/census-income.test.gz',
        delimiter=',',
        header=None,
        index_col=None,
        names=column_names
    )

    # First group of tasks according to the paper
    label_columns = ['income_50k', 'marital_stat']

    # One-hot encoding categorical columns
    categorical_columns = ['class_worker', 'det_ind_code', 'det_occ_code', 'education', 'hs_college', 'major_ind_code',
                           'major_occ_code', 'race', 'hisp_origin', 'sex', 'union_member', 'unemp_reason',
                           'full_or_part_emp', 'tax_filer_stat', 'region_prev_res', 'state_prev_res', 'det_hh_fam_stat',
                           'det_hh_summ', 'mig_chg_msa', 'mig_chg_reg', 'mig_move_reg', 'mig_same', 'mig_prev_sunbelt',
                           'fam_under_18', 'country_father', 'country_mother', 'country_self', 'citizenship',
                           'vet_question']
    train_raw_labels = train_df[label_columns]
    other_raw_labels = other_df[label_columns]
    transformed_train = pd.get_dummies(train_df.drop(label_columns, axis=1), columns=categorical_columns)
    transformed_other = pd.get_dummies(other_df.drop(label_columns, axis=1), columns=categorical_columns)

    # Filling the missing column in the other set
    transformed_other['det_hh_fam_stat_ Grandchild <18 ever marr not in subfamily'] = 0

    # One-hot encoding categorical labels
    train_income = to_categorical((train_raw_labels.income_50k == ' 50000+.').astype(int), num_classes=2)
    train_marital = to_categorical((train_raw_labels.marital_stat == ' Never married').astype(int), num_classes=2)
    other_income = to_categorical((other_raw_labels.income_50k == ' 50000+.').astype(int), num_classes=2)
    other_marital = to_categorical((other_raw_labels.marital_stat == ' Never married').astype(int), num_classes=2)

    dict_outputs = {
        'income': train_income.shape[1],
        'marital': train_marital.shape[1]
    }
    dict_train_labels = {
        'income': train_income,
        'marital': train_marital
    }
    dict_other_labels = {
        'income': other_income,
        'marital': other_marital
    }
    output_info = [(dict_outputs[key], key) for key in sorted(dict_outputs.keys())]

    # Split the other dataset into 1:1 validation to test according to the paper
    validation_indices = transformed_other.sample(frac=0.5, replace=False, random_state=SEED).index
    test_indices = list(set(transformed_other.index) - set(validation_indices))
    validation_data = transformed_other.iloc[validation_indices]
    validation_label = [dict_other_labels[key][validation_indices] for key in sorted(dict_other_labels.keys())]
    test_data = transformed_other.iloc[test_indices]
    test_label = [dict_other_labels[key][test_indices] for key in sorted(dict_other_labels.keys())]
    train_data = transformed_train
    train_label = [dict_train_labels[key] for key in sorted(dict_train_labels.keys())]

    return train_data, train_label, validation_data, validation_label, test_data, test_label, output_info

# %%
# Simple callback to print out ROC-AUC
class ROCCallback(Callback):
    def __init__(self, training_data, validation_data, test_data):
        self.train_X = training_data[0]
        self.train_Y = training_data[1]
        self.validation_X = validation_data[0]
        self.validation_Y = validation_data[1]
        self.test_X = test_data[0]
        self.test_Y = test_data[1]

    def on_train_begin(self, logs={}):
        return

    def on_train_end(self, logs={}):
        return

    def on_epoch_begin(self, epoch, logs={}):
        return

    def on_epoch_end(self, epoch, logs={}):
        train_prediction = self.model.predict(self.train_X)
        validation_prediction = self.model.predict(self.validation_X)
        test_prediction = self.model.predict(self.test_X)

        # Iterate through each task and output their ROC-AUC across different datasets
        for index, output_name in enumerate(self.model.output_names):
            train_roc_auc = roc_auc_score(self.train_Y[index], train_prediction[index])
            validation_roc_auc = roc_auc_score(self.validation_Y[index], validation_prediction[index])
            test_roc_auc = roc_auc_score(self.test_Y[index], test_prediction[index])
            print(
                'ROC-AUC-{}-Train: {} ROC-AUC-{}-Validation: {} ROC-AUC-{}-Test: {}'.format(
                    output_name, round(train_roc_auc, 4),
                    output_name, round(validation_roc_auc, 4),
                    output_name, round(test_roc_auc, 4)
                )
            )

        return

    def on_batch_begin(self, batch, logs={}):
        return

    def on_batch_end(self, batch, logs={}):
        return

# %%
# Load the data
train_data, train_label, validation_data, validation_label, test_data, test_label, output_info = data_preparation()
num_features = train_data.shape[1]

print('Training data shape = {}'.format(train_data.shape))
print('Validation data shape = {}'.format(validation_data.shape))
print('Test data shape = {}'.format(test_data.shape))

# Set up the input layer
input_layer = Input(shape=(num_features,))

# Set up MMoE layer
mmoe_layers = MMoE(
    units=4,
    num_experts=8,
    num_tasks=2
)(input_layer)

output_layers = []

# Build tower layer from MMoE layer
for index, task_layer in enumerate(mmoe_layers):
    tower_layer = Dense(
        units=8,
        activation='relu',
        kernel_initializer=VarianceScaling())(task_layer)
    output_layer = Dense(
        units=output_info[index][0],
        name=output_info[index][1],
        activation='softmax',
        kernel_initializer=VarianceScaling())(tower_layer)
    output_layers.append(output_layer)

# Compile model
model = Model(inputs=[input_layer], outputs=output_layers)
adam_optimizer = Adam()
model.compile(
    loss={'income': 'binary_crossentropy', 'marital': 'binary_crossentropy'},
    optimizer=adam_optimizer,
    metrics=['accuracy']
)

# Print out model architecture summary
model.summary()
# Out:
# Training data shape = (199523, 499)
# Validation data shape = (49881, 499)
# Test data shape = (49881, 499)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 499)]        0
# __________________________________________________________________________________________________
# m_mo_e (MMoE)                   [(None, 4), (None, 4 24000       input_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 8)            40          m_mo_e[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            40          m_mo_e[0][1]
# __________________________________________________________________________________________________
# income (Dense)                  (None, 2)            18          dense[0][0]
# __________________________________________________________________________________________________
# marital (Dense)                 (None, 2)            18          dense_1[0][0]
# ==================================================================================================
# Total params: 24,116
# Trainable params: 24,116
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Train the model
model.fit(
    x=train_data,
    y=train_label,
    validation_data=(validation_data, validation_label),
    callbacks=[
        ROCCallback(
            training_data=(train_data, train_label),
            validation_data=(validation_data, validation_label),
            test_data=(test_data, test_label)
        )
    ],
    epochs=40
)
# Out:
# Epoch 1/40
# 6236/6236 [==============================] - 65s 10ms/step - loss: 0.4758 - income_loss: 0.1846 - marital_loss: 0.2913 - income_accuracy: 0.9378 - marital_accuracy: 0.8905 - val_loss: 0.3819 - val_income_loss: 0.1631 - val_marital_loss: 0.2188 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9231
# ROC-AUC-income-Train: 0.9165 ROC-AUC-income-Validation: 0.917 ROC-AUC-income-Test: 0.9155
# ROC-AUC-marital-Train: 0.9613 ROC-AUC-marital-Validation: 0.9492 ROC-AUC-marital-Test: 0.9496
# Epoch 2/40
# 6236/6236 [==============================] - 57s 9ms/step - loss: 0.3061 - income_loss: 0.1530 - marital_loss: 0.1531 - income_accuracy: 0.9379 - marital_accuracy: 0.9409 - val_loss: 0.3584 - val_income_loss: 0.1495 - val_marital_loss: 0.2089 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9172
# ROC-AUC-income-Train: 0.9208 ROC-AUC-income-Validation: 0.92 ROC-AUC-income-Test: 0.9199
# ROC-AUC-marital-Train: 0.9869 ROC-AUC-marital-Validation: 0.9723 ROC-AUC-marital-Test: 0.9717
# Epoch 3/40
# 6236/6236 [==============================] - 57s 9ms/step - loss: 0.2802 - income_loss: 0.1488 - marital_loss: 0.1314 - income_accuracy: 0.9379 - marital_accuracy: 0.9452 - val_loss: 0.3731 - val_income_loss: 0.1747 - val_marital_loss: 0.1984 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9196
# ROC-AUC-income-Train: 0.9227 ROC-AUC-income-Validation: 0.9203 ROC-AUC-income-Test: 0.9195
# ROC-AUC-marital-Train: 0.9902 ROC-AUC-marital-Validation: 0.9754 ROC-AUC-marital-Test: 0.975
# Epoch 4/40
# 6236/6236 [==============================] - 63s 10ms/step - loss: 0.2728 - income_loss: 0.1454 - marital_loss: 0.1274 - income_accuracy: 0.9379 - marital_accuracy: 0.9467 - val_loss: 0.3751 - val_income_loss: 0.1460 - val_marital_loss: 0.2291 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9084
# ROC-AUC-income-Train: 0.9243 ROC-AUC-income-Validation: 0.9245 ROC-AUC-income-Test: 0.9243
# ROC-AUC-marital-Train: 0.9907 ROC-AUC-marital-Validation: 0.9741 ROC-AUC-marital-Test: 0.9736
# Epoch 5/40
# 6236/6236 [==============================] - 59s 10ms/step - loss: 0.2657 - income_loss: 0.1430 - marital_loss: 0.1227 - income_accuracy: 0.9379 - marital_accuracy: 0.9483 - val_loss: 0.4352 - val_income_loss: 0.1956 - val_marital_loss: 0.2396 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9051
# ROC-AUC-income-Train: 0.9219 ROC-AUC-income-Validation: 0.9195 ROC-AUC-income-Test: 0.9175
# ROC-AUC-marital-Train: 0.9899 ROC-AUC-marital-Validation: 0.9699 ROC-AUC-marital-Test: 0.9696
# Epoch 6/40
# 6236/6236 [==============================] - 61s 10ms/step - loss: 0.2643 - income_loss: 0.1427 - marital_loss: 0.1217 - income_accuracy: 0.9379 - marital_accuracy: 0.9484 - val_loss: 0.3986 - val_income_loss: 0.1621 - val_marital_loss: 0.2365 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9050
# ROC-AUC-income-Train: 0.928 ROC-AUC-income-Validation: 0.9231 ROC-AUC-income-Test: 0.9228
# ROC-AUC-marital-Train: 0.9908 ROC-AUC-marital-Validation: 0.9728 ROC-AUC-marital-Test: 0.9718
# Epoch 7/40
# 6236/6236 [==============================] - 55s 9ms/step - loss: 0.2625 - income_loss: 0.1418 - marital_loss: 0.1207 - income_accuracy: 0.9379 - marital_accuracy: 0.9490 - val_loss: 0.3947 - val_income_loss: 0.1648 - val_marital_loss: 0.2299 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9063
# ROC-AUC-income-Train: 0.9297 ROC-AUC-income-Validation: 0.9257 ROC-AUC-income-Test: 0.9252
# ROC-AUC-marital-Train: 0.9909 ROC-AUC-marital-Validation: 0.9707 ROC-AUC-marital-Test: 0.9699
# Epoch 8/40
# 6236/6236 [==============================] - 58s 9ms/step - loss: 0.2580 - income_loss: 0.1413 - marital_loss: 0.1167 - income_accuracy: 0.9380 - marital_accuracy: 0.9494 - val_loss: 0.4338 - val_income_loss: 0.1987 - val_marital_loss: 0.2352 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9054
# ROC-AUC-income-Train: 0.9336 ROC-AUC-income-Validation: 0.9291 ROC-AUC-income-Test: 0.9276
# ROC-AUC-marital-Train: 0.9907 ROC-AUC-marital-Validation: 0.9698 ROC-AUC-marital-Test: 0.9695
# Epoch 9/40
# 6236/6236 [==============================] - 61s 10ms/step - loss: 0.2558 - income_loss: 0.1401 - marital_loss: 0.1157 - income_accuracy: 0.9378 - marital_accuracy: 0.9501 - val_loss: 0.4045 - val_income_loss: 0.1511 - val_marital_loss: 0.2533 - val_income_accuracy: 0.9412 - val_marital_accuracy: 0.9027
# ROC-AUC-income-Train: 0.9321 ROC-AUC-income-Validation: 0.9304 ROC-AUC-income-Test: 0.9294
# ROC-AUC-marital-Train: 0.9898 ROC-AUC-marital-Validation: 0.9697 ROC-AUC-marital-Test: 0.9695
# Epoch 10/40
# 6236/6236 [==============================] - 58s 9ms/step - loss: 0.2525 - income_loss: 0.1380 - marital_loss: 0.1145 - income_accuracy: 0.9425 - marital_accuracy: 0.9502 - val_loss: 0.4033 - val_income_loss: 0.1699 - val_marital_loss: 0.2334 - val_income_accuracy: 0.9318 - val_marital_accuracy: 0.9079
# ROC-AUC-income-Train: 0.9253 ROC-AUC-income-Validation: 0.9199 ROC-AUC-income-Test: 0.9181
# ROC-AUC-marital-Train: 0.9912 ROC-AUC-marital-Validation: 0.9715 ROC-AUC-marital-Test: 0.9707
# Epoch 11/40
# 6236/6236 [==============================] - 55s 9ms/step - loss: 0.2502 - income_loss: 0.1371 - marital_loss: 0.1132 - income_accuracy: 0.9423 - marital_accuracy: 0.9503 - val_loss: 0.4140 - val_income_loss: 0.1832 - val_marital_loss: 0.2308 - val_income_accuracy: 0.9431 - val_marital_accuracy: 0.9087
# ROC-AUC-income-Train: 0.9401 ROC-AUC-income-Validation: 0.9349 ROC-AUC-income-Test: 0.9348
# ROC-AUC-marital-Train: 0.9924 ROC-AUC-marital-Validation: 0.9708 ROC-AUC-marital-Test: 0.9702
# Epoch 12/40
# 6236/6236 [==============================] - 60s 10ms/step - loss: 0.2472 - income_loss: 0.1359 - marital_loss: 0.1113 - income_accuracy: 0.9433 - marital_accuracy: 0.9513 - val_loss: 0.4771 - val_income_loss: 0.2266 - val_marital_loss: 0.2505 - val_income_accuracy: 0.9353 - val_marital_accuracy: 0.9065
# ROC-AUC-income-Train: 0.9306 ROC-AUC-income-Validation: 0.9241 ROC-AUC-income-Test: 0.9227
# ROC-AUC-marital-Train: 0.9902 ROC-AUC-marital-Validation: 0.9685 ROC-AUC-marital-Test: 0.9679
# Epoch 13/40
# 6236/6236 [==============================] - 61s 10ms/step - loss: 0.2472 - income_loss: 0.1371 - marital_loss: 0.1101 - income_accuracy: 0.9422 - marital_accuracy: 0.9512 - val_loss: 0.3737 - val_income_loss: 0.1447 - val_marital_loss: 0.2291 - val_income_accuracy: 0.9428 - val_marital_accuracy: 0.9088
# ROC-AUC-income-Train: 0.9295 ROC-AUC-income-Validation: 0.9275 ROC-AUC-income-Test: 0.9262
# ROC-AUC-marital-Train: 0.9931 ROC-AUC-marital-Validation: 0.9723 ROC-AUC-marital-Test: 0.9715
# Epoch 14/40
# 6236/6236 [==============================] - 56s 9ms/step - loss: 0.2479 - income_loss: 0.1382 - marital_loss: 0.1097 - income_accuracy: 0.9437 - marital_accuracy: 0.9521 - val_loss: 0.4290 - val_income_loss: 0.1990 - val_marital_loss: 0.2299 - val_income_accuracy: 0.9343 - val_marital_accuracy: 0.9086
# ROC-AUC-income-Train: 0.9299 ROC-AUC-income-Validation: 0.9251 ROC-AUC-income-Test: 0.9243
# ROC-AUC-marital-Train: 0.9934 ROC-AUC-marital-Validation: 0.9732 ROC-AUC-marital-Test: 0.9725
# Epoch 15/40
# 6236/6236 [==============================] - 57s 9ms/step - loss: 0.2445 - income_loss: 0.1360 - marital_loss: 0.1085 - income_accuracy: 0.9421 - marital_accuracy: 0.9523 - val_loss: 0.4257 - val_income_loss: 0.1806 - val_marital_loss: 0.2451 - val_income_accuracy: 0.9448 - val_marital_accuracy: 0.9064
# ROC-AUC-income-Train: 0.938 ROC-AUC-income-Validation: 0.9338 ROC-AUC-income-Test: 0.9333
# ROC-AUC-marital-Train: 0.9895 ROC-AUC-marital-Validation: 0.9672 ROC-AUC-marital-Test: 0.9664
# Epoch 16/40
# 6236/6236 [==============================] - 57s 9ms/step - loss: 0.2430 - income_loss: 0.1356 - marital_loss: 0.1075 - income_accuracy: 0.9421 - marital_accuracy: 0.9523 - val_loss: 0.4056 - val_income_loss: 0.1762 - val_marital_loss: 0.2295 - val_income_accuracy: 0.9452 - val_marital_accuracy: 0.9085
# ROC-AUC-income-Train: 0.9358 ROC-AUC-income-Validation: 0.933 ROC-AUC-income-Test: 0.9311
# ROC-AUC-marital-Train: 0.9934 ROC-AUC-marital-Validation: 0.9728 ROC-AUC-marital-Test: 0.972
# Epoch 17/40
# 6236/6236 [==============================] - 61s 10ms/step - loss: 0.2410 - income_loss: 0.1344 - marital_loss: 0.1066 - income_accuracy: 0.9448 - marital_accuracy: 0.9519 - val_loss: 0.4247 - val_income_loss: 0.1641 - val_marital_loss: 0.2606 - val_income_accuracy: 0.9454 - val_marital_accuracy: 0.9026
# ROC-AUC-income-Train: 0.9393 ROC-AUC-income-Validation: 0.9343 ROC-AUC-income-Test: 0.934
# ROC-AUC-marital-Train: 0.9927 ROC-AUC-marital-Validation: 0.9745 ROC-AUC-marital-Test: 0.9737
# Epoch 18/40
# 6236/6236 [==============================] - 57s 9ms/step - loss: 0.2426 - income_loss: 0.1380 - marital_loss: 0.1046 - income_accuracy: 0.9430 - marital_accuracy: 0.9547 - val_loss: 0.4342 - val_income_loss: 0.1788 - val_marital_loss: 0.2554 - val_income_accuracy: 0.9389 - val_marital_accuracy: 0.9094
# ROC-AUC-income-Train: 0.9334 ROC-AUC-income-Validation: 0.9281 ROC-AUC-income-Test: 0.9278
# ROC-AUC-marital-Train: 0.9916 ROC-AUC-marital-Validation: 0.9692 ROC-AUC-marital-Test: 0.9684
# Epoch 19/40
# 6236/6236 [==============================] - 63s 10ms/step - loss: 0.2393 - income_loss: 0.1341 - marital_loss: 0.1052 - income_accuracy: 0.9445 - marital_accuracy: 0.9557 - val_loss: 0.4046 - val_income_loss: 0.1689 - val_marital_loss: 0.2357 - val_income_accuracy: 0.9418 - val_marital_accuracy: 0.9094
# ROC-AUC-income-Train: 0.9363 ROC-AUC-income-Validation: 0.9312 ROC-AUC-income-Test: 0.9301
# ROC-AUC-marital-Train: 0.9936 ROC-AUC-marital-Validation: 0.9717 ROC-AUC-marital-Test: 0.9708
# Epoch 20/40
# 6236/6236 [==============================] - 61s 10ms/step - loss: 0.2365 - income_loss: 0.1339 - marital_loss: 0.1027 - income_accuracy: 0.9443 - marital_accuracy: 0.9553 - val_loss: 0.4305 - val_income_loss: 0.1949 - val_marital_loss: 0.2356 - val_income_accuracy: 0.9438 - val_marital_accuracy: 0.9116
# ROC-AUC-income-Train: 0.9427 ROC-AUC-income-Validation: 0.9369 ROC-AUC-income-Test: 0.9367
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9727 ROC-AUC-marital-Test: 0.9716
# Epoch 21/40
# 6236/6236 [==============================] - 61s 10ms/step - loss: 0.2395 - income_loss: 0.1346 - marital_loss: 0.1049 - income_accuracy: 0.9455 - marital_accuracy: 0.9556 - val_loss: 0.4188 - val_income_loss: 0.1666 - val_marital_loss: 0.2522 - val_income_accuracy: 0.9463 - val_marital_accuracy: 0.9061
# ROC-AUC-income-Train: 0.9403 ROC-AUC-income-Validation: 0.9359 ROC-AUC-income-Test: 0.9342
# ROC-AUC-marital-Train: 0.9927 ROC-AUC-marital-Validation: 0.9699 ROC-AUC-marital-Test: 0.9686
# Epoch 22/40
# 6236/6236 [==============================] - 56s 9ms/step - loss: 0.2378 - income_loss: 0.1351 - marital_loss: 0.1027 - income_accuracy: 0.9450 - marital_accuracy: 0.9561 - val_loss: 0.4183 - val_income_loss: 0.1785 - val_marital_loss: 0.2398 - val_income_accuracy: 0.9436 - val_marital_accuracy: 0.9087
# ROC-AUC-income-Train: 0.9404 ROC-AUC-income-Validation: 0.9353 ROC-AUC-income-Test: 0.9348
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9702 ROC-AUC-marital-Test: 0.9691
# Epoch 23/40
# 6236/6236 [==============================] - 57s 9ms/step - loss: 0.2361 - income_loss: 0.1343 - marital_loss: 0.1019 - income_accuracy: 0.9456 - marital_accuracy: 0.9557 - val_loss: 0.4320 - val_income_loss: 0.1892 - val_marital_loss: 0.2427 - val_income_accuracy: 0.9464 - val_marital_accuracy: 0.9078
# ROC-AUC-income-Train: 0.9393 ROC-AUC-income-Validation: 0.9352 ROC-AUC-income-Test: 0.9334
# ROC-AUC-marital-Train: 0.9927 ROC-AUC-marital-Validation: 0.9738 ROC-AUC-marital-Test: 0.9727
# Epoch 24/40
# 6236/6236 [==============================] - 57s 9ms/step - loss: 0.2350 - income_loss: 0.1339 - marital_loss: 0.1012 - income_accuracy: 0.9462 - marital_accuracy: 0.9558 - val_loss: 0.4663 - val_income_loss: 0.2297 - val_marital_loss: 0.2365 - val_income_accuracy: 0.9447 - val_marital_accuracy: 0.9108
# ROC-AUC-income-Train: 0.942 ROC-AUC-income-Validation: 0.9339 ROC-AUC-income-Test: 0.9328
# ROC-AUC-marital-Train: 0.9931 ROC-AUC-marital-Validation: 0.9719 ROC-AUC-marital-Test: 0.9709
# Epoch 25/40
# 6236/6236 [==============================] - 63s 10ms/step - loss: 0.2362 - income_loss: 0.1333 - marital_loss: 0.1029 - income_accuracy: 0.9450 - marital_accuracy: 0.9560 - val_loss: 0.4702 - val_income_loss: 0.2294 - val_marital_loss: 0.2408 - val_income_accuracy: 0.9448 - val_marital_accuracy: 0.9117
# ROC-AUC-income-Train: 0.9388 ROC-AUC-income-Validation: 0.9324 ROC-AUC-income-Test: 0.9317
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.9752 ROC-AUC-marital-Test: 0.9744
# Epoch 26/40
# 6236/6236 [==============================] - 63s 10ms/step - loss: 0.2331 - income_loss: 0.1325 - marital_loss: 0.1006 - income_accuracy: 0.9465 - marital_accuracy: 0.9564 - val_loss: 0.4478 - val_income_loss: 0.2152 - val_marital_loss: 0.2325 - val_income_accuracy: 0.9421 - val_marital_accuracy: 0.9106
# ROC-AUC-income-Train: 0.944 ROC-AUC-income-Validation: 0.9383 ROC-AUC-income-Test: 0.9372
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.9719 ROC-AUC-marital-Test: 0.9707
# Epoch 27/40
# 6236/6236 [==============================] - 61s 10ms/step - loss: 0.2355 - income_loss: 0.1336 - marital_loss: 0.1019 - income_accuracy: 0.9464 - marital_accuracy: 0.9565 - val_loss: 0.3948 - val_income_loss: 0.1544 - val_marital_loss: 0.2405 - val_income_accuracy: 0.9459 - val_marital_accuracy: 0.9103
# ROC-AUC-income-Train: 0.9421 ROC-AUC-income-Validation: 0.9365 ROC-AUC-income-Test: 0.9359
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9696 ROC-AUC-marital-Test: 0.9687
# Epoch 28/40
# 6236/6236 [==============================] - 61s 10ms/step - loss: 0.2345 - income_loss: 0.1327 - marital_loss: 0.1018 - income_accuracy: 0.9470 - marital_accuracy: 0.9570 - val_loss: 0.4196 - val_income_loss: 0.1776 - val_marital_loss: 0.2420 - val_income_accuracy: 0.9438 - val_marital_accuracy: 0.9054
# ROC-AUC-income-Train: 0.9398 ROC-AUC-income-Validation: 0.9343 ROC-AUC-income-Test: 0.9343
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9674 ROC-AUC-marital-Test: 0.9664
# Epoch 29/40
# 6236/6236 [==============================] - 62s 10ms/step - loss: 0.2317 - income_loss: 0.1320 - marital_loss: 0.0997 - income_accuracy: 0.9479 - marital_accuracy: 0.9567 - val_loss: 0.4209 - val_income_loss: 0.1768 - val_marital_loss: 0.2441 - val_income_accuracy: 0.9442 - val_marital_accuracy: 0.9098
# ROC-AUC-income-Train: 0.9446 ROC-AUC-income-Validation: 0.9378 ROC-AUC-income-Test: 0.9376
# ROC-AUC-marital-Train: 0.9936 ROC-AUC-marital-Validation: 0.9713 ROC-AUC-marital-Test: 0.9704
# Epoch 30/40
# 6236/6236 [==============================] - 59s 10ms/step - loss: 0.2327 - income_loss: 0.1317 - marital_loss: 0.1010 - income_accuracy: 0.9474 - marital_accuracy: 0.9562 - val_loss: 0.4577 - val_income_loss: 0.2015 - val_marital_loss: 0.2562 - val_income_accuracy: 0.9436 - val_marital_accuracy: 0.9079
# ROC-AUC-income-Train: 0.9417 ROC-AUC-income-Validation: 0.9358 ROC-AUC-income-Test: 0.9353
# ROC-AUC-marital-Train: 0.9935 ROC-AUC-marital-Validation: 0.9726 ROC-AUC-marital-Test: 0.9717
# Epoch 31/40
# 6236/6236 [==============================] - 59s 9ms/step - loss: 0.2342 - income_loss: 0.1319 - marital_loss: 0.1022 - income_accuracy: 0.9471 - marital_accuracy: 0.9564 - val_loss: 0.4340 - val_income_loss: 0.1971 - val_marital_loss: 0.2369 - val_income_accuracy: 0.9431 - val_marital_accuracy: 0.9065
# ROC-AUC-income-Train: 0.9423 ROC-AUC-income-Validation: 0.9354 ROC-AUC-income-Test: 0.9356
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.969 ROC-AUC-marital-Test: 0.9679
# Epoch 32/40
# 6236/6236 [==============================] - 61s 10ms/step - loss: 0.2331 - income_loss: 0.1337 - marital_loss: 0.0994 - income_accuracy: 0.9469 - marital_accuracy: 0.9566 - val_loss: 0.4468 - val_income_loss: 0.1847 - val_marital_loss: 0.2622 - val_income_accuracy: 0.9456 - val_marital_accuracy: 0.9009
# ROC-AUC-income-Train: 0.9426 ROC-AUC-income-Validation: 0.9374 ROC-AUC-income-Test: 0.9361
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9664 ROC-AUC-marital-Test: 0.965
# Epoch 33/40
# 6236/6236 [==============================] - 62s 10ms/step - loss: 0.2310 - income_loss: 0.1318 - marital_loss: 0.0992 - income_accuracy: 0.9481 - marital_accuracy: 0.9563 - val_loss: 0.4215 - val_income_loss: 0.1604 - val_marital_loss: 0.2610 - val_income_accuracy: 0.9443 - val_marital_accuracy: 0.9041
# ROC-AUC-income-Train: 0.9428 ROC-AUC-income-Validation: 0.9362 ROC-AUC-income-Test: 0.936
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9663 ROC-AUC-marital-Test: 0.9653
# Epoch 34/40
# 6236/6236 [==============================] - 58s 9ms/step - loss: 0.2324 - income_loss: 0.1323 - marital_loss: 0.1000 - income_accuracy: 0.9477 - marital_accuracy: 0.9574 - val_loss: 0.4161 - val_income_loss: 0.1688 - val_marital_loss: 0.2473 - val_income_accuracy: 0.9452 - val_marital_accuracy: 0.9031
# ROC-AUC-income-Train: 0.9448 ROC-AUC-income-Validation: 0.9388 ROC-AUC-income-Test: 0.9382
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.966 ROC-AUC-marital-Test: 0.9647
# Epoch 35/40
# 6236/6236 [==============================] - 62s 10ms/step - loss: 0.2288 - income_loss: 0.1308 - marital_loss: 0.0980 - income_accuracy: 0.9492 - marital_accuracy: 0.9575 - val_loss: 0.4312 - val_income_loss: 0.1707 - val_marital_loss: 0.2605 - val_income_accuracy: 0.9459 - val_marital_accuracy: 0.9017
# ROC-AUC-income-Train: 0.939 ROC-AUC-income-Validation: 0.9318 ROC-AUC-income-Test: 0.9325
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9662 ROC-AUC-marital-Test: 0.965
# Epoch 36/40
# 6236/6236 [==============================] - 63s 10ms/step - loss: 0.2321 - income_loss: 0.1332 - marital_loss: 0.0989 - income_accuracy: 0.9471 - marital_accuracy: 0.9564 - val_loss: 0.4223 - val_income_loss: 0.1798 - val_marital_loss: 0.2425 - val_income_accuracy: 0.9409 - val_marital_accuracy: 0.8961
# ROC-AUC-income-Train: 0.9338 ROC-AUC-income-Validation: 0.9261 ROC-AUC-income-Test: 0.926
# ROC-AUC-marital-Train: 0.992 ROC-AUC-marital-Validation: 0.9683 ROC-AUC-marital-Test: 0.9672
# Epoch 37/40
# 6236/6236 [==============================] - 59s 9ms/step - loss: 0.2315 - income_loss: 0.1317 - marital_loss: 0.0998 - income_accuracy: 0.9474 - marital_accuracy: 0.9560 - val_loss: 0.4639 - val_income_loss: 0.1918 - val_marital_loss: 0.2721 - val_income_accuracy: 0.9456 - val_marital_accuracy: 0.9058
# ROC-AUC-income-Train: 0.9408 ROC-AUC-income-Validation: 0.9344 ROC-AUC-income-Test: 0.9341
# ROC-AUC-marital-Train: 0.9935 ROC-AUC-marital-Validation: 0.9691 ROC-AUC-marital-Test: 0.9681
# Epoch 38/40
# 6236/6236 [==============================] - 63s 10ms/step - loss: 0.2351 - income_loss: 0.1340 - marital_loss: 0.1012 - income_accuracy: 0.9460 - marital_accuracy: 0.9567 - val_loss: 0.4327 - val_income_loss: 0.1852 - val_marital_loss: 0.2475 - val_income_accuracy: 0.9429 - val_marital_accuracy: 0.9060
# ROC-AUC-income-Train: 0.9399 ROC-AUC-income-Validation: 0.9311 ROC-AUC-income-Test: 0.9313
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9689 ROC-AUC-marital-Test: 0.9679
# Epoch 39/40
# 6236/6236 [==============================] - 64s 10ms/step - loss: 0.2298 - income_loss: 0.1318 - marital_loss: 0.0981 - income_accuracy: 0.9465 - marital_accuracy: 0.9576 - val_loss: 0.4442 - val_income_loss: 0.1787 - val_marital_loss: 0.2655 - val_income_accuracy: 0.9440 - val_marital_accuracy: 0.9052
# ROC-AUC-income-Train: 0.9443 ROC-AUC-income-Validation: 0.9364 ROC-AUC-income-Test: 0.9358
# ROC-AUC-marital-Train: 0.9934 ROC-AUC-marital-Validation: 0.9688 ROC-AUC-marital-Test: 0.9679
# Epoch 40/40
# 6236/6236 [==============================] - 60s 10ms/step - loss: 0.2287 - income_loss: 0.1308 - marital_loss: 0.0979 - income_accuracy: 0.9486 - marital_accuracy: 0.9568 - val_loss: 0.4741 - val_income_loss: 0.1989 - val_marital_loss: 0.2752 - val_income_accuracy: 0.9413 - val_marital_accuracy: 0.9070
# ROC-AUC-income-Train: 0.9371 ROC-AUC-income-Validation: 0.9296 ROC-AUC-income-Test: 0.929
# ROC-AUC-marital-Train: 0.9935 ROC-AUC-marital-Validation: 0.9695 ROC-AUC-marital-Test: 0.9686
